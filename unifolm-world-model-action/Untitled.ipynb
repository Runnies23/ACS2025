# %%
import warnings
warnings.filterwarnings("ignore")

from unifolm_wma_run.models.samplers.ddim import DDIMSampler
print("Hello World")
# Out:
# Hello World

# %%
import sys
for p in sys.path:
    print(p)
# Out:
# /mnt/ASC1664/run_workspace/unifolm-world-model-action/src
# /mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python310.zip
# /mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10
# /mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/lib-dynload
#
# /mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages
# /mnt/ASC1664/ZLUDA-unifolm-wma-0-dual/src
# /tmp/tmpc7mwd787

# %%
import torch
torch.__version__
# Out:
# '2.9.1+rocm7.1.1.git351ff442'

# %%
import torch
torch.__version__
# Out:
# '2.10.0+rocm7.1'

# %%
# !python -m xformers.info
# Out:
# WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.3.1+cu121 with CUDA 1201 (you have 2.10.0+rocm7.1)
#     Python  3.10.14 (you have 3.10.18)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details
# Traceback (most recent call last):
#   File "/mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "/mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/xformers/__init__.py", line 12, in <module>
#     from .checkpoint import (  # noqa: E402, F401
# ...

# %%
# !pip uninstall -y torchvision
# Out:
# Found existing installation: torchvision 0.25.0+rocm7.1
# Uninstalling torchvision-0.25.0+rocm7.1:
#   Successfully uninstalled torchvision-0.25.0+rocm7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import torchvision
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torchvision
#
# ModuleNotFoundError: No module named 'torchvision'

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/rocm7.1
# Out:
# Looking in indexes: https://download.pytorch.org/whl/rocm7.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 9.5 MB/s  0:00:00m 7.4 MB/s eta 0:00:01
# ...

# %%
import torchvision
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torchvision
#
# File /mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/torchvision/__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File /mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# ...

# %%
# !python -c "import torch; print(f'Torch version: {torch.__version__}'); print(f'{torch.__version__}') ; print(f'Is ROCm/CUDA available?: {torch.cuda.is_available()}'); print(f'Device count: {torch.cuda.device_count()}')"
# Out:
# Torch version: 2.10.0+rocm7.1
# 2.10.0+rocm7.1
# Is ROCm/CUDA available?: True
# Device count: 1

# %%
pip cache purge
