# %%
# !amd-smi
# Out:
# Permission needed to access required GPU device node(s):
#   - /dev/dri/card0: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card1: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card2: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card3: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card4: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card5: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card6: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card7: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card8: Permission denied; owner=root(0):video(44);
#
# You can try:
#   • Add your user to the group that owns these devices:
#       sudo usermod -aG <group> "$USER"
#
# +------------------------------------------------------------------------------+
# | AMD-SMI 26.2.0+021c61fc      amdgpu version: 6.16.6   ROCm version: 7.1.1    |
# ...

# %%
# !python unifolm-world-model-action/scripts/evaluation/world_model_interaction.py \
    --seed 123 \
    --ckpt_path "/mnt/ASC1664/unifolm-wma-0-dual/ASC26-Embodied-World-Model-Optimization/ckpts/unifolm_wma_dual.ckpt" \
    --config ./unifolm-world-model-action/configs/inference/world_model_interaction.yaml \
    --savedir "/mnt/$USER/run_workspace/results/unitree_z1_dual_arm_stackbox" \
    --bs 1 --height 320 --width 512 \
    --unconditional_guidance_scale 1.0 \
    --ddim_steps 50 \
    --ddim_eta 1.0 \
    --prompt_dir "./ASC26-Embodied-World-Model-Optimization/unitree_z1_dual_arm_stackbox/case1/" \
    --dataset "unitree_z1_dual_arm_stackbox" \
    --video_length 16 \
    --frame_stride 4 \
    --n_action_steps 16 \
    --exe_steps 16 \
    --n_iter 12 \
    --timestep_spacing 'uniform_trailing' \
    --guidance_rescale 0.7 \
    --perframe_ae
# Out:
# 2026-02-16 03:26:03.184953: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-16 03:26:03.224249: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-16 03:26:03.224288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-16 03:26:03.225908: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
res_dir="unitree_z1_dual_arm_stackbox/case1"
dataset="unitree_z1_dual_arm_stackbox"

# !python unifolm-world-model-action/scripts/evaluation/world_model_interaction.py \
        --seed 123 \
        --ckpt_path "/mnt/ASC1664/unifolm-wma-0-dual/ASC26-Embodied-World-Model-Optimization/ckpts/unifolm_wma_dual.ckpt" \
        --config ./unifolm-world-model-action/configs/inference/world_model_interaction.yaml \
        --savedir "/mnt/$USER/run_workspace/results/unitree_z1_dual_arm_stackbox/output" \
        --bs 1 --height 320 --width 512 \
        --unconditional_guidance_scale 1.0 \
        --ddim_steps 50 \
        --ddim_eta 1.0 \
        --prompt_dir "./ASC26-Embodied-World-Model-Optimization/unitree_z1_dual_arm_stackbox/case1/world_model_interaction_prompts" \
        --dataset ${dataset} \
        --video_length 16 \
        --frame_stride 4 \
        --n_action_steps 16 \
        --exe_steps 16 \
        --n_iter 7 \
        --timestep_spacing 'uniform_trailing' \
        --guidance_rescale 0.7 \
        --perframe_ae
# Out:
# Traceback (most recent call last):
#   File "/mnt/ASC1664/run_workspace/unifolm-world-model-action/scripts/evaluation/world_model_interaction.py", line 2, in <module>
#     import pandas as pd
#   File "/mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/pandas/__init__.py", line 22, in <module>
#     from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#   File "/mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/pandas/compat/__init__.py", line 25, in <module>
#     from pandas.compat.numpy import (
#   File "/mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/pandas/compat/numpy/__init__.py", line 4, in <module>
#     from pandas.util.version import Version
#   File "/mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/pandas/util/__init__.py", line 2, in <module>
#     from pandas.util._decorators import (  # noqa:F401
# ...

# %%
# !pip uninstall pandas -y
# !pip install pandas==2.0.0
import pandas as pd
# Out:
# Found existing installation: pandas 2.3.3
# Uninstalling pandas-2.3.3:
#   Successfully uninstalled pandas-2.3.3
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 24.1 MB/s  0:00:00a 0:00:01 eta 0:00:01
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unifolm-wma-run 0.0.1 requires xformers==0.0.27, but you have xformers 0.0.35+88dcc2ce.d20260213 which is incompatible.
# unifolm-wma 0.0.1 requires torch==2.3.1, but you have torch 2.9.1+rocm7.1.1.lw.git351ff442 which is incompatible.
# unifolm-wma 0.0.1 requires torchvision==0.18.1, but you have torchvision 0.24.0+rocm7.1.1.gitb919bd0c which is incompatible.
# unifolm-wma 0.0.1 requires xformers==0.0.27, but you have xformers 0.0.35+88dcc2ce.d20260213 which is incompatible.
# ...
# ---------------------------------------------------------------------------
# ...

# %%
# !pip uninstall -y numpy scikit-learn pandas

# !pip install \
numpy==1.24.2 \
scikit-learn==1.5.1 \
pandas==2.0.0
# Out:
# Found existing installation: numpy 1.24.2
# Uninstalling numpy-1.24.2:
#   Successfully uninstalled numpy-1.24.2
# Found existing installation: scikit-learn 1.5.1
# Uninstalling scikit-learn-1.5.1:
#   Successfully uninstalled scikit-learn-1.5.1
# Found existing installation: pandas 2.0.0
# Uninstalling pandas-2.0.0:
#   Successfully uninstalled pandas-2.0.0
# ...
#   Using cached pandas-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 24.9 MB/s  0:00:00a 0:00:010:00:012
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 35.5 MB/s  0:00:00 68.9 MB/s eta 0:00:01
# Using cached pandas-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:━━━━━━━━━━━━━━━━━━━━━━━━━ 0/3 [numpy]
#       Successfully uninstalled numpy-2.2.6━━━━━━━━━━━━ 0/3 [numpy]
# ...

# %%
# !pip uninstall -y numpy pandas scikit-learn scipy

# !pip install numpy pandas scikit-learn

import pandas as pd
# Out:
# Found existing installation: numpy 1.24.2
# Uninstalling numpy-1.24.2:
#   Successfully uninstalled numpy-1.24.2
# Found existing installation: pandas 2.0.0
# Uninstalling pandas-2.0.0:
#   Successfully uninstalled pandas-2.0.0
# Found existing installation: scikit-learn 1.5.1
# Uninstalling scikit-learn-1.5.1:
#   Successfully uninstalled scikit-learn-1.5.1
# Found existing installation: scipy 1.15.3
# Uninstalling scipy-1.15.3:
#   Successfully uninstalled scipy-1.15.3
# ...
#   Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# ...
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 5.4 MB/s  0:00:03 eta 0:00:010:01:01
# Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 16.3 MB/s  0:00:006.2 MB/s eta 0:00:01
# ...

# %%
# !python -c "import numpy, pandas, sklearn; print(numpy.__version__, pandas.__version__, sklearn.__version__)"

# %%
# !ls
# Out:
# 3980_profiling.out			 jupyter.sh
# ASC26-Embodied-World-Model-Optimization  profiling.sh
# compare					 Readme.md
# compare_zip.ipynb			 run.sh
# configs					 unifolm-world-model-action
# download_weight.sh			 Untitled.ipynb
# download_weigth.ipynb			 weight_clip
# jupyter.out

# %%
# !pwd
# Out:
# /mnt/ASC1664/run_workspace

# %%
# !python ./unifolm-world-model-action/test.py
# Out:
# Traceback (most recent call last):
#   File "/mnt/ASC1664/run_workspace/./unifolm-world-model-action/test.py", line 1, in <module>
#     from unifolm_wma_run.models.samplers.ddim import DDIMSampler
# ModuleNotFoundError: No module named 'unifolm_wma_run'

# %%
# !python ./unifolm-world-model-action/test.py
# Out:
# WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.3.1+cu121 with CUDA 1201 (you have 2.10.0+rocm7.1)
#     Python  3.10.14 (you have 3.10.18)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details

# %%
import torch 
torch.__version__
# Out:
# '2.9.1+rocm7.1.1.git351ff442'

# %%
# !amd-smi
# Out:
# Permission needed to access required GPU device node(s):
#   - /dev/dri/card0: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card1: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card2: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card3: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card4: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card5: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card6: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card7: Permission denied; owner=root(0):video(44);
#   - /dev/dri/card8: Permission denied; owner=root(0):video(44);
#
# You can try:
#   • Add your user to the group that owns these devices:
#       sudo usermod -aG <group> "$USER"
#
# +------------------------------------------------------------------------------+
# | AMD-SMI 26.2.0+021c61fc      amdgpu version: 6.16.6   ROCm version: 7.1.1    |
# ...

# %%
# !python unifolm-world-model-action/scripts/evaluation/world_model_interaction.py \
    --seed 123 \
    --ckpt_path "/mnt/ASC1664/unifolm-wma-0-dual/ASC26-Embodied-World-Model-Optimization/ckpts/unifolm_wma_dual.ckpt" \
    --config ./unifolm-world-model-action/configs/inference/world_model_interaction.yaml \
    --savedir "/mnt/$USER//run_workspace/result/force/testing/unitree_z1_stackbox" \
    --bs 1 --height 320 --width 512 \
    --unconditional_guidance_scale 1.0 \
    --ddim_steps 50 \
    --ddim_eta 1.0 \
    --prompt_dir "unifolm-world-model-action/examples/world_model_interaction_prompts" \
    --dataset "unitree_z1_stackbox" \
    --video_length 16 \
    --frame_stride 4 \
    --n_action_steps 16 \
    --exe_steps 16 \
    --n_iter 12 \
    --timestep_spacing 'uniform_trailing' \
    --guidance_rescale 0.7 \
    --perframe_ae
# Out:
# 2026-02-16 11:13:53.607517: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-16 11:13:53.786838: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-16 11:13:53.786905: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-16 11:13:53.789289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python unifolm-world-model-action/scripts/evaluation/world_model_interaction.py \
    --seed 123 \
    --ckpt_path "/mnt/ASC1664/unifolm-wma-0-dual/ASC26-Embodied-World-Model-Optimization/ckpts/unifolm_wma_dual.ckpt" \
    --config "./unifolm-world-model-action/configs/inference/world_model_interaction.yaml" \
    --savedir "/mnt/$USER/run_workspace/result/force/testing/unitree_z1_stackbox" \
    --bs 1 --height 320 --width 512 \
    --unconditional_guidance_scale 1.0 \
    --ddim_steps 50 \
    --ddim_eta 1.0 \
    --prompt_dir "unifolm-world-model-action/examples/world_model_interaction_prompts" \
    --dataset "unitree_z1_stackbox" \
    --video_length 16 \
    --frame_stride 4 \
    --n_action_steps 16 \
    --exe_steps 16 \
    --n_iter 12 \
    --timestep_spacing 'uniform_trailing' \
    --guidance_rescale 0.7 \
    --perframe_ae
# Out:
# 2026-02-16 13:01:58.631687: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-16 13:01:59.621145: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-16 13:01:59.621212: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-16 13:01:59.628716: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import torchvision
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torchvision
#
# File /mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/torchvision/__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File /mnt/ASC1664/miniconda3/envs/unifolm-wma_run/lib/python3.10/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# ...
